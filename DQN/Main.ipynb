# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from car_dqn import CarRacingDQN
from IPython.display import clear_output
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import gym
import _thread
import re
import sys
import numpy as np
import racing_car
import keyboard

# %%
train_episodes = 15000
save_freq_episodes = train_episodes/100 
finished = False
render_var = False
frame_skip = 3

# This initializes the CNN.
model_config = dict(
    min_epsilon=0.05,
    max_negative_rewards=8,
    min_experience_size=int(100),
    experience_capacity=int(150000),
    num_frame_stack=frame_skip,
    frame_skip=frame_skip,
    train_freq=frame_skip,
    batchsize=64,
    epsilon_decay_steps=int(100000),
    target_network_update_freq=int(1000), #Updates the target network every 10000 global steps by copying them from the prediction network to the target network
    gamma=0.95,
    render=render_var,
)

dqn_scores = []
eps_history = []
avg_score_all = [0]

env = racing_car.CarRacing()

tf.compat.v1.reset_default_graph
tf.compat.v1.disable_eager_execution()

dqn_agent = CarRacingDQN(env=env, **model_config)
dqn_agent.build_graph()
sess = tf.compat.v1.InteractiveSession()
dqn_agent.session = sess
clear_output()

# %%
load_checkpoint = False
checkpoint_path = "checkpoints/train_1" # 2 is a good 13000 episode training session
opendir = checkpoint_path + '.txt'
rewards_checkpoint_file = 'checkpoints/rewards/'
if load_checkpoint:
    text_results = open(opendir, "w")

#Initialize save checkpoints
saver = tf.compat.v1.train.Saver(max_to_keep=1000) #max number of checkpoints = 500
#Choice to load checkpoints
if load_checkpoint:
    train_episodes = 110
    save_freq_episodes = 0
    print("loading the latest checkpoint from %s" % checkpoint_path)
    ckpt = tf.train.get_checkpoint_state(checkpoint_path)
    assert ckpt, "checkpoint path %s not found" % checkpoint_path
    global_counter = int(re.findall("-(\d+)$", ckpt.model_checkpoint_path)[0])
    saver.restore(sess, ckpt.model_checkpoint_path)
    dqn_agent.global_counter = global_counter
    render = render_var
else:
    if checkpoint_path is not None:
        assert not os.path.exists(checkpoint_path), \
            "checkpoint path already exists but load_checkpoint is false"

    tf.compat.v1.global_variables_initializer().run()

    
def save_checkpoint():
    if not os.path.exists(checkpoint_path):
        os.makedirs(checkpoint_path)
    p = os.path.join(checkpoint_path, "m.ckpt")
    saver.save(sess, p)
    print("saved to %s - %d" % (p, dqn_agent.global_counter))


def one_episode(eps_history,dqn_scores,avg_score_all,render,load_checkpoint):
    score, reward, frames, epsilon = dqn_agent.play_episode(render, load_checkpoint)

    eps_history.append(epsilon)

    dqn_scores.append(score)
    i = dqn_agent.episode_counter
    avg_score = np.mean(dqn_scores[max(0, i - 100):(i + 1)])
    avg_score_all.append(avg_score)
    max_avg_score = max(avg_score_all)
    if avg_score >= max_avg_score:
        new_max = ' => New HighScore! <= '
        highscore = True
    else:
        new_max = ''
        highscore = False

    strm = ("#> episode: %i | score: %.2f | total steps: %i | epsilon: %.5f | average 100 score: %.2f" %
            (i, score, dqn_agent.global_counter, epsilon, avg_score))

    print(strm + new_max)

    text_results = open(opendir, "a")
    text_results.write(strm + new_max + '\n')
    text_results.close()

    if not load_checkpoint:
        save_cond = (
            dqn_agent.episode_counter % save_freq_episodes == 0
            and checkpoint_path is not None
            and dqn_agent.do_training
        )
        if save_cond or (highscore and dqn_agent.episode_counter > 100):
            save_checkpoint()

    return eps_history,dqn_scores,avg_score_all

def input_thread(list):
    input("...enter to stop after current episode\n")
    list.append("OK")


def main_loop(eps_history,dqn_scores,avg_score_all,render,load_checkpoint):
    while True:
        if dqn_agent.do_training and dqn_agent.episode_counter >= train_episodes:
            print('break2')
            break

        # if keyboard.is_pressed('q'):
        #     break

        print(dqn_agent.episode_counter)

        if (dqn_agent.episode_counter + 1) % 100 == 0:
            dqn_agent.env.close()
            dqn_agent.env = racing_car.CarRacing()
            print('##'*30)
            print('TEST FULL RESET Environment')
            print('##'*30)

        eps_history,dqn_scores,avg_score_all = one_episode(eps_history,dqn_scores,avg_score_all,render,load_checkpoint)

        if (dqn_agent.episode_counter + 1) % 10 == 0:   
            print('... saving rewards history ...')

            #===================================Episode Reward========================
            name = 'episode_reward_train_1'
            episode_reward_name = os.path.join(rewards_checkpoint_file, name+'.txt')
            episode_rewards_file = open(episode_reward_name, 'w')
            for row in np.array(dqn_scores).reshape(len(dqn_scores),1):
                np.savetxt(episode_rewards_file, row)
            episode_rewards_file.close()

            #====================================AVG Reward========================
            name = 'avg_reward_train_1'
            avg_reward_name = os.path.join(rewards_checkpoint_file, name+'.txt')
            avg_rewards_file = open(avg_reward_name, 'w')
            for row in np.array(avg_score_all).reshape(len(avg_score_all),1):
                np.savetxt(avg_rewards_file, row)
            avg_rewards_file.close()



    print("done")
    exit()
    return eps_history,dqn_scores,avg_score_all

    
# if train_episodes > 0 and dqn_agent.episode_counter < train_episodes:
#     print("now training... you can early stop with enter...")
#     print("##########")
#     sys.stdout.flush()
#     render = render_var
#     main_loop(eps_history,dqn_scores,avg_score_all,render,load_checkpoint)
#     save_checkpoint()
#     dqn_agent.env.close()
#     print("ok training done")

    
if train_episodes > 0 and dqn_agent.episode_counter < train_episodes and not load_checkpoint :
    print("now training... you can early stop with enter...")
    print("##########")
    sys.stdout.flush()
    render = render_var
    main_loop(eps_history,dqn_scores,avg_score_all,render,load_checkpoint)
    save_checkpoint()
    print("ok training done")
    
else:
    print("now just playing...")
    sys.stdout.flush()
    main_loop(eps_history,dqn_scores,avg_score_all,render,load_checkpoint)
    plt.imshow(dqn_agent.env.state.T)
# Out:
# | epsilon: 0.05000 | average 100 score: 656.49
# 8354
# Track generation: 1151..1447 -> 296-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1011..1275 -> 264-tiles track
# #> episode: 8355 | score: 787.51 | total steps: 1372119 | epsilon: 0.05000 | average 100 score: 661.47
# 8355
# Track generation: 1119..1403 -> 284-tiles track
# #> episode: 8356 | score: 364.26 | total steps: 1372224 | epsilon: 0.05000 | average 100 score: 659.23
# 8356
# Track generation: 1175..1473 -> 298-tiles track
# #> episode: 8357 | score: 916.56 | total steps: 1372446 | epsilon: 0.05000 | average 100 score: 659.19
# 8357
# Track generation: 1120..1404 -> 284-tiles track
# #> episode: 8358 | score: 360.43 | total steps: 1372552 | epsilon: 0.05000 | average 100 score: 658.39
# 8358
# Track generation: 1075..1348 -> 273-tiles track
# #> episode: 8359 | score: 876.38 | total steps: 1372768 | epsilon: 0.05000 | average 100 score: 658.31
# ... saving rewards history ...
# 8359
# Track generation: 1000..1254 -> 254-tiles track
# #> episode: 8360 | score: 933.80 | total steps: 1372989 | epsilon: 0.05000 | average 100 score: 662.97
# 8360
# Track generation: 1079..1362 -> 283-tiles track
# #> episode: 8361 | score: 881.74 | total steps: 1373265 | epsilon: 0.05000 | average 100 score: 662.54
# 8361
# Track generation: 1215..1523 -> 308-tiles track
# #> episode: 8362 | score: 908.90 | total steps: 1373569 | epsilon: 0.05000 | average 100 score: 664.46
# 8362
# Track generation: 1095..1373 -> 278-tiles track
# #> episode: 8363 | score: 918.07 | total steps: 1373806 | epsilon: 0.05000 | average 100 score: 668.22
# 8363
# Track generation: 1164..1459 -> 295-tiles track
# #> episode: 8364 | score: 871.08 | total steps: 1374043 | epsilon: 0.05000 | average 100 score: 667.67
# 8364
# Track generation: 1270..1592 -> 322-tiles track
# #> episode: 8365 | score: 888.45 | total steps: 1374311 | epsilon: 0.05000 | average 100 score: 667.87
# 8365
# Track generation: 1009..1274 -> 265-tiles track
# #> episode: 8366 | score: 890.91 | total steps: 1374561 | epsilon: 0.05000 | average 100 score: 673.69
# 8366
# Track generation: 1191..1493 -> 302-tiles track
# #> episode: 8367 | score: 628.93 | total steps: 1374768 | epsilon: 0.05000 | average 100 score: 677.71
# 8367
# Track generation: 1294..1622 -> 328-tiles track
# #> episode: 8368 | score: 894.17 | total steps: 1375080 | epsilon: 0.05000 | average 100 score: 679.19
# 8368
# Track generation: 1138..1427 -> 289-tiles track
# #> episode: 8369 | score: 312.38 | total steps: 1375173 | epsilon: 0.05000 | average 100 score: 673.04
# ... saving rewards history ...
# 8369
# Track generation: 1231..1543 -> 312-tiles track
# #> episode: 8370 | score: 891.26 | total steps: 1375439 | epsilon: 0.05000 | average 100 score: 673.22
# 8370
# Track generation: 1073..1345 -> 272-tiles track
# #> episode: 8371 | score: 504.94 | total steps: 1375564 | epsilon: 0.05000 | average 100 score: 673.31
# 8371
# Track generation: 960..1205 -> 245-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1332..1669 -> 337-tiles track
# #> episode: 8372 | score: 798.63 | total steps: 1375888 | epsilon: 0.05000 | average 100 score: 676.80
# 8372
# Track generation: 1120..1406 -> 286-tiles track
# #> episode: 8373 | score: 897.23 | total steps: 1376137 | epsilon: 0.05000 | average 100 score: 682.54
# 8373
# Track generation: 1206..1512 -> 306-tiles track
# #> episode: 8374 | score: 874.53 | total steps: 1376435 | epsilon: 0.05000 | average 100 score: 681.86
# 8374
# Track generation: 1187..1488 -> 301-tiles track
# #> episode: 8375 | score: 887.17 | total steps: 1376700 | epsilon: 0.05000 | average 100 score: 681.37
# 8375
# Track generation: 1262..1582 -> 320-tiles track
# #> episode: 8376 | score: 881.35 | total steps: 1376991 | epsilon: 0.05000 | average 100 score: 689.59
# 8376
# Track generation: 1153..1452 -> 299-tiles track
# #> episode: 8377 | score: 891.12 | total steps: 1377298 | epsilon: 0.05000 | average 100 score: 689.85
# 8377
# Track generation: 1174..1472 -> 298-tiles track
# #> episode: 8378 | score: 355.71 | total steps: 1377403 | epsilon: 0.05000 | average 100 score: 684.65
# 8378
# Track generation: 1188..1489 -> 301-tiles track
# #> episode: 8379 | score: 892.87 | total steps: 1377649 | epsilon: 0.05000 | average 100 score: 688.92
# ... saving rewards history ...
# 8379
# Track generation: 1100..1379 -> 279-tiles track
# #> episode: 8380 | score: 880.33 | total steps: 1377904 | epsilon: 0.05000 | average 100 score: 693.95
# 8380
# Track generation: 1152..1444 -> 292-tiles track
# #> episode: 8381 | score: 903.48 | total steps: 1378157 | epsilon: 0.05000 | average 100 score: 697.75
# 8381
# Track generation: 1224..1534 -> 310-tiles track
# #> episode: 8382 | score: 865.01 | total steps: 1378402 | epsilon: 0.05000 | average 100 score: 699.39
# 8382
# Track generation: 1103..1391 -> 288-tiles track
# #> episode: 8383 | score: 170.11 | total steps: 1378497 | epsilon: 0.05000 | average 100 score: 697.75
# 8383
# Track generation: 1156..1450 -> 294-tiles track
# #> episode: 8384 | score: 918.66 | total steps: 1378734 | epsilon: 0.05000 | average 100 score: 704.41
# 8384
# Track generation: 1044..1309 -> 265-tiles track
# #> episode: 8385 | score: 905.80 | total steps: 1378947 | epsilon: 0.05000 | average 100 score: 705.93
# 8385
# Track generation: 1193..1495 -> 302-tiles track
# #> episode: 8386 | score: 309.47 | total steps: 1379045 | epsilon: 0.05000 | average 100 score: 700.00
# 8386
# Track generation: 1116..1406 -> 290-tiles track
# #> episode: 8387 | score: 892.66 | total steps: 1379299 | epsilon: 0.05000 | average 100 score: 703.99
# 8387
# Track generation: 1031..1299 -> 268-tiles track
# #> episode: 8388 | score: 548.55 | total steps: 1379468 | epsilon: 0.05000 | average 100 score: 700.15
# 8388
# Track generation: 1165..1460 -> 295-tiles track
# #> episode: 8389 | score: 888.08 | total steps: 1379705 | epsilon: 0.05000 | average 100 score: 700.46
# ... saving rewards history ...
# 8389
# Track generation: 1209..1511 -> 302-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1021..1284 -> 263-tiles track
# #> episode: 8390 | score: 897.55 | total steps: 1379932 | epsilon: 0.05000 | average 100 score: 700.51
# 8390
# Track generation: 1171..1468 -> 297-tiles track
# #> episode: 8391 | score: 405.59 | total steps: 1380044 | epsilon: 0.05000 | average 100 score: 695.63
# 8391
# Track generation: 1036..1299 -> 263-tiles track
# #> episode: 8392 | score: 911.27 | total steps: 1380238 | epsilon: 0.05000 | average 100 score: 695.78
# 8392
# Track generation: 1252..1569 -> 317-tiles track
# #> episode: 8393 | score: 757.52 | total steps: 1380445 | epsilon: 0.05000 | average 100 score: 699.37
# 8393
# Track generation: 1050..1322 -> 272-tiles track
# #> episode: 8394 | score: 543.10 | total steps: 1380615 | epsilon: 0.05000 | average 100 score: 697.86
# 8394
# Track generation: 1173..1475 -> 302-tiles track
# #> episode: 8395 | score: 856.78 | total steps: 1380882 | epsilon: 0.05000 | average 100 score: 700.32
# 8395
# Track generation: 1129..1424 -> 295-tiles track
# #> episode: 8396 | score: 579.45 | total steps: 1381048 | epsilon: 0.05000 | average 100 score: 706.05
# 8396
# Track generation: 1124..1409 -> 285-tiles track
# #> episode: 8397 | score: 872.26 | total steps: 1381286 | epsilon: 0.05000 | average 100 score: 710.52
# 8397
# Track generation: 1066..1337 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# #> episode: 8398 | score: 901.62 | total steps: 1381544 | epsilon: 0.05000 | average 100 score: 710.55
# 8398
# Track generation: 1184..1484 -> 300-tiles track
# #> episode: 8399 | score: 575.36 | total steps: 1381722 | epsilon: 0.05000 | average 100 score: 707.76
# ... saving rewards history ...
# 8399
# ############################################################
# TEST FULL RESET Environment
# ############################################################
# Track generation: 1067..1338 -> 271-tiles track
# #> episode: 8400 | score: 923.89 | total steps: 1381951 | epsilon: 0.05000 | average 100 score: 708.20
# saved to checkpoints/train_1\m.ckpt - 1381951
# 8400
# Track generation: 1123..1413 -> 290-tiles track
# #> episode: 8401 | score: 920.64 | total steps: 1382204 | epsilon: 0.05000 | average 100 score: 708.29
# 8401
# Track generation: 1173..1470 -> 297-tiles track
# #> episode: 8402 | score: 886.56 | total steps: 1382447 | epsilon: 0.05000 | average 100 score: 713.86
# 8402
# Track generation: 1073..1352 -> 279-tiles track
# #> episode: 8403 | score: 506.55 | total steps: 1382617 | epsilon: 0.05000 | average 100 score: 718.37
# 8403
# Track generation: 1148..1439 -> 291-tiles track
# #> episode: 8404 | score: 916.61 | total steps: 1382849 | epsilon: 0.05000 | average 100 score: 718.43
# 8404
# Track generation: 1174..1472 -> 298-tiles track
# #> episode: 8405 | score: 894.33 | total steps: 1383089 | epsilon: 0.05000 | average 100 score: 722.09
# 8405
# Track generation: 1224..1534 -> 310-tiles track
# #> episode: 8406 | score: 270.43 | total steps: 1383180 | epsilon: 0.05000 | average 100 score: 720.52
# 8406
# Track generation: 1036..1299 -> 263-tiles track
# #> episode: 8407 | score: 897.25 | total steps: 1383408 | epsilon: 0.05000 | average 100 score: 720.55
# 8407
# Track generation: 1286..1612 -> 326-tiles track
# #> episode: 8408 | score: 269.66 | total steps: 1383504 | epsilon: 0.05000 | average 100 score: 719.69
# 8408
# Track generation: 1180..1479 -> 299-tiles track
# #> episode: 8409 | score: 651.84 | total steps: 1383669 | epsilon: 0.05000 | average 100 score: 716.88
# ... saving rewards history ...
# 8409
# Track generation: 952..1194 -> 242-tiles track
# #> episode: 8410 | score: 947.00 | total steps: 1383846 | epsilon: 0.05000 | average 100 score: 723.12
# 8410
# Track generation: 1264..1584 -> 320-tiles track
# #> episode: 8411 | score: 390.03 | total steps: 1383967 | epsilon: 0.05000 | average 100 score: 717.86
# 8411
# Track generation: 1147..1438 -> 291-tiles track
# #> episode: 8412 | score: 919.60 | total steps: 1384212 | epsilon: 0.05000 | average 100 score: 725.29
# 8412
# Track generation: 968..1221 -> 253-tiles track
# #> episode: 8413 | score: 934.80 | total steps: 1384430 | epsilon: 0.05000 | average 100 score: 725.66
# 8413
# Track generation: 1072..1344 -> 272-tiles track
# #> episode: 8414 | score: 501.25 | total steps: 1384555 | epsilon: 0.05000 | average 100 score: 725.83
# 8414
# Track generation: 936..1182 -> 246-tiles track
# #> episode: 8415 | score: 857.95 | total steps: 1384770 | epsilon: 0.05000 | average 100 score: 725.71
# 8415
# Track generation: 1260..1579 -> 319-tiles track
# #> episode: 8416 | score: 902.99 | total steps: 1385020 | epsilon: 0.05000 | average 100 score: 725.59
# 8416
# Track generation: 1203..1508 -> 305-tiles track
# #> episode: 8417 | score: 926.21 | total steps: 1385255 | epsilon: 0.05000 | average 100 score: 726.14
# 8417
# Track generation: 1284..1609 -> 325-tiles track
# #> episode: 8418 | score: 879.56 | total steps: 1385533 | epsilon: 0.05000 | average 100 score: 730.39
# 8418
# Track generation: 1258..1577 -> 319-tiles track
# #> episode: 8419 | score: 296.14 | total steps: 1385636 | epsilon: 0.05000 | average 100 score: 730.14
# ... saving rewards history ...
# 8419
# Track generation: 1064..1340 -> 276-tiles track
# #> episode: 8420 | score: 1.27 | total steps: 1385656 | epsilon: 0.05000 | average 100 score: 721.42
# 8420
# Track generation: 1031..1293 -> 262-tiles track
# #> episode: 8421 | score: 939.30 | total steps: 1385859 | epsilon: 0.05000 | average 100 score: 721.90
# 8421
# Track generation: 1159..1453 -> 294-tiles track
# #> episode: 8422 | score: 326.15 | total steps: 1385955 | epsilon: 0.05000 | average 100 score: 720.32
# 8422
# Track generation: 1107..1388 -> 281-tiles track
# #> episode: 8423 | score: 756.41 | total steps: 1386136 | epsilon: 0.05000 | average 100 score: 721.03
# 8423
# Track generation: 1167..1463 -> 296-tiles track
# #> episode: 8424 | score: 917.14 | total steps: 1386367 | epsilon: 0.05000 | average 100 score: 721.58
# 8424
# Track generation: 1134..1421 -> 287-tiles track
# #> episode: 8425 | score: 912.81 | total steps: 1386611 | epsilon: 0.05000 | average 100 score: 725.11
# 8425
# Track generation: 1284..1609 -> 325-tiles track
# #> episode: 8426 | score: 309.77 | total steps: 1386741 | epsilon: 0.05000 | average 100 score: 723.77
# 8426
# Track generation: 1247..1563 -> 316-tiles track
# #> episode: 8427 | score: 637.16 | total steps: 1386924 | epsilon: 0.05000 | average 100 score: 721.03
# 8427
# Track generation: 1239..1553 -> 314-tiles track
# #> episode: 8428 | score: 904.93 | total steps: 1387177 | epsilon: 0.05000 | average 100 score: 721.03
# 8428
# Track generation: 1187..1488 -> 301-tiles track
# #> episode: 8429 | score: 875.07 | total steps: 1387449 | epsilon: 0.05000 | average 100 score: 720.76
# ... saving rewards history ...
# 8429
# Track generation: 1297..1625 -> 328-tiles track
# #> episode: 8430 | score: 895.44 | total steps: 1387716 | epsilon: 0.05000 | average 100 score: 729.60
# 8430
# Track generation: 1244..1559 -> 315-tiles track
# #> episode: 8431 | score: 857.36 | total steps: 1388011 | epsilon: 0.05000 | average 100 score: 729.61
# 8431
# Track generation: 1151..1443 -> 292-tiles track
# #> episode: 8432 | score: 851.96 | total steps: 1388241 | epsilon: 0.05000 | average 100 score: 728.96
# 8432
# Track generation: 1181..1488 -> 307-tiles track
# #> episode: 8433 | score: 869.71 | total steps: 1388501 | epsilon: 0.05000 | average 100 score: 728.88
# 8433
# Track generation: 1053..1323 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1029..1293 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 938..1177 -> 239-tiles track
# #> episode: 8434 | score: 874.27 | total steps: 1388710 | epsilon: 0.05000 | average 100 score: 731.45
# 8434
# Track generation: 1055..1323 -> 268-tiles track
# #> episode: 8435 | score: 909.13 | total steps: 1388938 | epsilon: 0.05000 | average 100 score: 737.35
# 8435
# Track generation: 1105..1393 -> 288-tiles track
# #> episode: 8436 | score: 647.69 | total steps: 1389160 | epsilon: 0.05000 | average 100 score: 735.17
# 8436
# Track generation: 1147..1442 -> 295-tiles track
# #> episode: 8437 | score: 0.80 | total steps: 1389180 | epsilon: 0.05000 | average 100 score: 726.02
# 8437
# Track generation: 1163..1458 -> 295-tiles track
# #> episode: 8438 | score: 937.20 | total steps: 1389390 | epsilon: 0.05000 | average 100 score: 726.68
# 8438
# Track generation: 1131..1418 -> 287-tiles track
# #> episode: 8439 | score: 911.12 | total steps: 1389628 | epsilon: 0.05000 | average 100 score: 727.04
# ... saving rewards history ...
# 8439
# Track generation: 1104..1384 -> 280-tiles track
# #> episode: 8440 | score: 912.18 | total steps: 1389861 | epsilon: 0.05000 | average 100 score: 732.78
# 8440
# Track generation: 1127..1420 -> 293-tiles track
# #> episode: 8441 | score: 885.83 | total steps: 1390116 | epsilon: 0.05000 | average 100 score: 732.97
# 8441
# Track generation: 1227..1538 -> 311-tiles track
# #> episode: 8442 | score: 897.17 | total steps: 1390405 | epsilon: 0.05000 | average 100 score: 733.11
# 8442
# Track generation: 1273..1595 -> 322-tiles track
# #> episode: 8443 | score: 894.68 | total steps: 1390673 | epsilon: 0.05000 | average 100 score: 735.08
# 8443
# Track generation: 1114..1397 -> 283-tiles track
# #> episode: 8444 | score: 934.70 | total steps: 1390891 | epsilon: 0.05000 | average 100 score: 739.09
# 8444
# Track generation: 1124..1409 -> 285-tiles track
# #> episode: 8445 | score: 903.81 | total steps: 1391106 | epsilon: 0.05000 | average 100 score: 744.94
# 8445
# Track generation: 1094..1378 -> 284-tiles track
# #> episode: 8446 | score: 5.43 | total steps: 1391135 | epsilon: 0.05000 | average 100 score: 735.99
# 8446
# Track generation: 1294..1621 -> 327-tiles track
# #> episode: 8447 | score: 863.92 | total steps: 1391425 | epsilon: 0.05000 | average 100 score: 737.28
# 8447
# Track generation: 1265..1590 -> 325-tiles track
# #> episode: 8448 | score: 879.95 | total steps: 1391784 | epsilon: 0.05000 | average 100 score: 737.05
# 8448
# Track generation: 1156..1449 -> 293-tiles track
# #> episode: 8449 | score: 904.63 | total steps: 1392022 | epsilon: 0.05000 | average 100 score: 737.37
# ... saving rewards history ...
# 8449
# Track generation: 1119..1403 -> 284-tiles track
# #> episode: 8450 | score: 866.43 | total steps: 1392267 | epsilon: 0.05000 | average 100 score: 737.26
# 8450
# Track generation: 1115..1398 -> 283-tiles track
# #> episode: 8451 | score: 616.27 | total steps: 1392435 | epsilon: 0.05000 | average 100 score: 734.31
# 8451
# Track generation: 1164..1459 -> 295-tiles track
# #> episode: 8452 | score: 866.97 | total steps: 1392663 | epsilon: 0.05000 | average 100 score: 739.84
# 8452
# Track generation: 1122..1406 -> 284-tiles track
# #> episode: 8453 | score: 424.56 | total steps: 1392779 | epsilon: 0.05000 | average 100 score: 740.64
# 8453
# Track generation: 964..1211 -> 247-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1424..1784 -> 360-tiles track
# #> episode: 8454 | score: 695.22 | total steps: 1393080 | epsilon: 0.05000 | average 100 score: 744.71
# 8454
# Track generation: 1067..1338 -> 271-tiles track
# #> episode: 8455 | score: 907.07 | total steps: 1393291 | epsilon: 0.05000 | average 100 score: 745.90
# 8455
# Track generation: 1107..1388 -> 281-tiles track
# #> episode: 8456 | score: 905.70 | total steps: 1393522 | epsilon: 0.05000 | average 100 score: 751.32 => New HighScore! <=
# saved to checkpoints/train_1\m.ckpt - 1393522
# 8456
# Track generation: 1007..1271 -> 264-tiles track
# #> episode: 8457 | score: 496.93 | total steps: 1393678 | epsilon: 0.05000 | average 100 score: 747.12
# 8457
# Track generation: 1251..1568 -> 317-tiles track
# #> episode: 8458 | score: 699.25 | total steps: 1393921 | epsilon: 0.05000 | average 100 score: 750.51
# 8458
# Track generation: 1252..1584 -> 332-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1100..1379 -> 279-tiles track
# #> episode: 8459 | score: 924.41 | total steps: 1394149 | epsilon: 0.05000 | average 100 score: 750.99
# ... saving rewards history ...
# 8459
# Track generation: 1103..1383 -> 280-tiles track
# #> episode: 8460 | score: 888.92 | total steps: 1394352 | epsilon: 0.05000 | average 100 score: 750.54
# 8460
# Track generation: 1078..1357 -> 279-tiles track
# #> episode: 8461 | score: 918.11 | total steps: 1394589 | epsilon: 0.05000 | average 100 score: 750.90
# 8461
# Track generation: 1367..1713 -> 346-tiles track
# #> episode: 8462 | score: 256.86 | total steps: 1394699 | epsilon: 0.05000 | average 100 score: 744.38
# 8462
# Track generation: 1131..1418 -> 287-tiles track
# #> episode: 8463 | score: 555.80 | total steps: 1394851 | epsilon: 0.05000 | average 100 score: 740.76
# 8463
# Track generation: 1095..1377 -> 282-tiles track
# #> episode: 8464 | score: 914.97 | total steps: 1395087 | epsilon: 0.05000 | average 100 score: 741.20
# 8464
# Track generation: 1187..1488 -> 301-tiles track
# #> episode: 8465 | score: 915.87 | total steps: 1395323 | epsilon: 0.05000 | average 100 score: 741.47
# 8465
# Track generation: 1107..1388 -> 281-tiles track
# #> episode: 8466 | score: 692.16 | total steps: 1395492 | epsilon: 0.05000 | average 100 score: 739.49
# 8466
# Track generation: 1171..1474 -> 303-tiles track
# #> episode: 8467 | score: 328.54 | total steps: 1395611 | epsilon: 0.05000 | average 100 score: 736.48
# 8467
# Track generation: 1040..1308 -> 268-tiles track
# #> episode: 8468 | score: 913.62 | total steps: 1395849 | epsilon: 0.05000 | average 100 score: 736.68
# 8468
# Track generation: 1108..1389 -> 281-tiles track
# #> episode: 8469 | score: 252.20 | total steps: 1395925 | epsilon: 0.05000 | average 100 score: 736.08
# ... saving rewards history ...
# 8469
# Track generation: 1212..1519 -> 307-tiles track
# #> episode: 8470 | score: 890.79 | total steps: 1396191 | epsilon: 0.05000 | average 100 score: 736.07
# 8470
# Track generation: 1319..1653 -> 334-tiles track
# #> episode: 8471 | score: 884.78 | total steps: 1396495 | epsilon: 0.05000 | average 100 score: 739.87
# 8471
# Track generation: 1167..1469 -> 302-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1fe87d9b1bc9> in <module>
#     139     sys.stdout.flush()
#     140     render = render_var
# --> 141     main_loop(eps_history,dqn_scores,avg_score_all,render,load_checkpoint)
#     142     save_checkpoint()
#     143     print("ok training done")
#
# <ipython-input-3-1fe87d9b1bc9> in main_loop(eps_history, dqn_scores, avg_score_all, render, load_checkpoint)
#      95             print('##'*30)
#      96
# ---> 97         eps_history,dqn_scores,avg_score_all = one_episode(eps_history,dqn_scores,avg_score_all,render,load_checkpoint)
#      98
#      99         if (dqn_agent.episode_counter + 1) % 10 == 0:
#
# <ipython-input-3-1fe87d9b1bc9> in one_episode(eps_history, dqn_scores, avg_score_all, render, load_checkpoint)
#      36
#      37 def one_episode(eps_history,dqn_scores,avg_score_all,render,load_checkpoint):
# ---> 38     score, reward, frames, epsilon = dqn_agent.play_episode(render, load_checkpoint)
#      39
#      40     eps_history.append(epsilon)
#
# c:\Users\jesse\Documents\University of Pretoria\Master's\Models\RL\Model 1 - DQN\Adapted\dqn.py in play_episode(self, render, load_checkpoint)
#     257                 )
#     258                 if train_cond:
# --> 259                     self.train()
#     260
#     261             if done:
#
# c:\Users\jesse\Documents\University of Pretoria\Master's\Models\RL\Model 1 - DQN\Adapted\dqn.py in train(self)
#     181         }
#     182         fd1 = {ph: batch[k] for ph, k in fd.items()}
# --> 183         self.session.run([self.train_op], fd1)
#     184
#     185     def play_episode(self, render, load_checkpoint):
#
# D:\Software\ANACONDA\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# D:\Software\ANACONDA\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# D:\Software\ANACONDA\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1366
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#    1370     else:
#
# D:\Software\ANACONDA\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1373   def _do_call(self, fn, *args):
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#    1377       message = compat.as_text(e.message)
#
# D:\Software\ANACONDA\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1357       # Ensure any changes to the graph are reflected in the runtime.
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#    1361
#
# D:\Software\ANACONDA\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1449   def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#    1453                                             run_metadata)
#
# KeyboardInterrupt:

# %%
dqn_agent.do_training, dqn_agent.episode_counter, train_episodes, list
# Out:
# (True, 1, 15000, list)

# %%
plt.imshow(dqn_agent.env.state.T)

# %%
plt.figure(0,figsize = (10,5))
plt.plot(dqn_scores,'k',label = 'Independent episode scores')
plt.plot(avg_score_all,'r--', label = '100 episode moving average score')
plt.plot([0,110],[900,900],'g',label = 'Open AI performance indicator')
plt.ylabel('$\mathcal{R}$')
plt.xlabel('Episodes')
plt.grid()
plt.ylim(-10,1000)
plt.legend()

# %%
plt.plot(dqn_scores)
plt.plot(avg_score_all)

# %%
array = np.loadtxt('March11_checkpoints/rewards/avg_reward_train_3.txt')

# %%
plt.plot(array)

# %%
plt.plot(dqn_scores)
plt.plot(avg_score_all)

# %%
x = 4
assert x>5 
print('through')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-57e8ed8b22fd> in <module>
#       1 x = 4
# ----> 2 assert x>5
#       3 print('through')
#
# AssertionError:
